# %%
import numpy as np
import pandas as pd
from xgboost import *
from sklearn.metrics import *
from pandas.api.types import is_string_dtype, is_numeric_dtype
from sklearn.preprocessing import LabelEncoder
from sklearn.grid_search import GridSearchCV
import re
# Out:
# /Users/gongtingpeng/anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# /Users/gongtingpeng/anaconda3/lib/python3.6/site-packages/sklearn/grid_search.py:42: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. This module will be removed in 0.20.
#   DeprecationWarning)

# %%
train = pd.read_feather('tmp/train-lat-long')
test = pd.read_feather('tmp/test-lat-long')

# %%
X = train.drop(['any_spot', 'Real.Spots'], axis=1)
Y = train['any_spot']

# %%
#Handles class imbalance through sampling
classDistribution = train['any_spot'].value_counts()
print('Class imbalance:')
print(classDistribution)
train = train.sample(frac=1).reset_index(drop=True)
zero = train[train['any_spot']==0].tail(classDistribution.min())
one = train[train['any_spot']==1]
train_data = zero.append(one)
del zero, one
train_data = train_data.sample(frac=1).reset_index(drop=True)
#del train
print('Class imbalance evened out:')
print(train_data['any_spot'].value_counts())
# Out:
# Class imbalance:
# 0    699
# 1    401
# Name: any_spot, dtype: int64
# Class imbalance evened out:
# 1    401
# 0    401
# Name: any_spot, dtype: int64

# %%
X['lat_from'], X['lon_from'] = X.lat_long_from.str.split(',').str

_, X['lat_from'] = X.lat_from.str.split(':').str

X['lat_from'] =  X['lat_from'].astype(str).astype(float)

_, X['lon_from'] = X.lon_from.str.split(':').str
X['lon_from'] =  X['lon_from'].astype(str).astype(float)

X = X.drop(['lat_long_from'], axis = 1)

X['lat_to'], X['lon_to'] = X.lat_long_to.str.split(',').str

_, X['lat_to'] = X.lat_to.str.split(':').str
X['lat_to'] =  X['lat_to'].astype(str).astype(float)

_, X['lon_to'] = X.lon_to.str.split(':').str
X['lon_to'] =  X['lon_to'].astype(str).astype(float)

X = X.drop(['lat_long_to'], axis = 1)
X = X.drop(['combined'], axis = 1)

test['lat_from'], test['lon_from'] = test.lat_long_from.str.split(',').str

_, test['lat_from'] = test.lat_from.str.split(':').str

test['lat_from'] =  test['lat_from'].astype(str).astype(float)

_, test['lon_from'] = test.lon_from.str.split(':').str
test['lon_from'] =  test['lon_from'].astype(str).astype(float)

test = test.drop(['lat_long_from'], axis = 1)

test['lat_to'], test['lon_to'] = test.lat_long_to.str.split(',').str

_, test['lat_to'] = test.lat_to.str.split(':').str
test['lat_to'] =  test['lat_to'].astype(str).astype(float)

_, test['lon_to'] = test.lon_to.str.split(':').str
test['lon_to'] =  test['lon_to'].astype(str).astype(float)

test = test.drop(['lat_long_to'], axis = 1)
test = test.drop(['combined'], axis = 1)

# %%
X = X.drop(['STREET_NAME_x', 'STREET_NAME_y'], axis = 1)
test = test.drop(['STREET_NAME_x', 'STREET_NAME_y'], axis = 1)

category = ["Street", "From", "To","from_to"]

le = LabelEncoder()
for cat in category:
    le.fit(X[cat])
    X[cat] = le.transform(X[cat])
    test[cat] = le.transform(test[cat])

X = X.fillna(0)
test = test.fillna(0)

# %%
param_grid = {'n_estimators' : [200, 500],
'min_child_weight':[2, 4, 6], 
'learning_rate' : [ 0.1, 0.2, 0.3],
'subsample' : [0.6, 0.8],
'colsample_bytree' : [0.5, 0.8],
'max_depth':[2, 4, 6]
}

f_scorer = make_scorer(fbeta_score, beta=0.5)

gd_search = GridSearchCV(estimator = XGBClassifier(objective = 'binary:logistic', nthread = 4, scale_pos_weight = 1, seed = 1), 
param_grid = param_grid, scoring ='roc_auc', iid = False, cv = 5, verbose = 5, n_jobs = -1)
gd_search.fit(X, Y)
# Out:
# Fitting 5 folds for each of 216 candidates, totalling 1080 fits
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=2, n_estimators=200, subsample=0.6
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=2, n_estimators=200, subsample=0.6
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=2, n_estimators=200, subsample=0.6
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=2, n_estimators=200, subsample=0.6
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=2, n_estimators=200, subsample=0.6
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=2, n_estimators=200, subsample=0.8
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=2, n_estimators=200, subsample=0.8
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=2, n_estimators=200, subsample=0.8
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=2, n_estimators=200, subsample=0.6, score=0.314821 -   0.3s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=2, n_estimators=200, subsample=0.8
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=2, n_estimators=200, subsample=0.6, score=0.549030 -   0.3s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=2, n_estimators=200, subsample=0.8
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=2, n_estimators=200, subsample=0.6, score=0.498661 -   0.5s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=2, n_estimators=500, subsample=0.6
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.3s
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=2, n_estimators=200, subsample=0.8, score=0.526071 -   0.5s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=2, n_estimators=500, subsample=0.6
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=2, n_estimators=200, subsample=0.6, score=0.860342 -   0.6s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=2, n_estimators=500, subsample=0.6
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=2, n_estimators=200, subsample=0.8, score=0.594709 -   0.6s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=2, n_estimators=500, subsample=0.6
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=2, n_estimators=200, subsample=0.8, score=0.267232 -   0.6s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=2, n_estimators=500, subsample=0.6
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=2, n_estimators=200, subsample=0.6, score=0.583482 -   0.7s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=2, n_estimators=500, subsample=0.8
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=2, n_estimators=200, subsample=0.8, score=0.588839 -   0.5s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=2, n_estimators=500, subsample=0.8
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=2, n_estimators=200, subsample=0.8, score=0.858993 -   0.6s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=2, n_estimators=500, subsample=0.8
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=2, n_estimators=500, subsample=0.6, score=0.840378 -   0.8s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=2, n_estimators=500, subsample=0.8
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=2, n_estimators=500, subsample=0.6, score=0.242054 -   0.9s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=2, n_estimators=500, subsample=0.8
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=2, n_estimators=500, subsample=0.6, score=0.548325 -   1.0s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=4, n_estimators=200, subsample=0.6
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=2, n_estimators=500, subsample=0.6, score=0.556518 -   0.9s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=4, n_estimators=200, subsample=0.6
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=2, n_estimators=500, subsample=0.8, score=0.542328 -   0.9s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=4, n_estimators=200, subsample=0.6
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=2, n_estimators=500, subsample=0.8, score=0.229196 -   0.9s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=4, n_estimators=200, subsample=0.6
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=2, n_estimators=500, subsample=0.6, score=0.451339 -   1.1s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=4, n_estimators=200, subsample=0.6
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=2, n_estimators=500, subsample=0.8, score=0.467143 -   0.9s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=4, n_estimators=200, subsample=0.8
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=4, n_estimators=200, subsample=0.6, score=0.567108 -   0.5s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=4, n_estimators=200, subsample=0.8
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=4, n_estimators=200, subsample=0.6, score=0.343750 -   0.4s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=4, n_estimators=200, subsample=0.8
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=4, n_estimators=200, subsample=0.6, score=0.861421 -   0.4s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=4, n_estimators=200, subsample=0.8
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=4, n_estimators=200, subsample=0.6, score=0.486964 -   0.6s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=4, n_estimators=200, subsample=0.8
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=4, n_estimators=200, subsample=0.8, score=0.633862 -   0.4s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=4, n_estimators=500, subsample=0.6
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=4, n_estimators=200, subsample=0.6, score=0.580089 -   0.6s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=4, n_estimators=500, subsample=0.6
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=4, n_estimators=200, subsample=0.8, score=0.280625 -   0.5s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=4, n_estimators=500, subsample=0.6
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=4, n_estimators=200, subsample=0.8, score=0.520268 -   0.5s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=4, n_estimators=500, subsample=0.6
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=2, n_estimators=500, subsample=0.8, score=0.834982 -   1.1s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=4, n_estimators=500, subsample=0.6
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=2, n_estimators=500, subsample=0.8, score=0.553839 -   1.2s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=4, n_estimators=500, subsample=0.8
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=4, n_estimators=200, subsample=0.8, score=0.586875 -   0.5s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=4, n_estimators=500, subsample=0.8
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=4, n_estimators=200, subsample=0.8, score=0.857734 -   0.5s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=4, n_estimators=500, subsample=0.8
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=4, n_estimators=500, subsample=0.6, score=0.516931 -   1.1s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=4, n_estimators=500, subsample=0.8
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=4, n_estimators=500, subsample=0.6, score=0.451071 -   0.9s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=4, n_estimators=500, subsample=0.8
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=4, n_estimators=500, subsample=0.6, score=0.257679 -   1.1s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=6, n_estimators=200, subsample=0.6
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=4, n_estimators=500, subsample=0.6, score=0.839388 -   1.0s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=6, n_estimators=200, subsample=0.6
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=4, n_estimators=500, subsample=0.8, score=0.233304 -   1.0s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=6, n_estimators=200, subsample=0.6
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=4, n_estimators=500, subsample=0.8, score=0.463750 -   0.9s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=6, n_estimators=200, subsample=0.6
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=4, n_estimators=500, subsample=0.6, score=0.552143 -   1.2s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=6, n_estimators=200, subsample=0.6
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=4, n_estimators=500, subsample=0.8, score=0.558113 -   1.1s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=6, n_estimators=200, subsample=0.8
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=6, n_estimators=200, subsample=0.6, score=0.575838 -   0.4s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=6, n_estimators=200, subsample=0.8
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=6, n_estimators=200, subsample=0.6, score=0.372946 -   0.4s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=6, n_estimators=200, subsample=0.8
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=6, n_estimators=200, subsample=0.6, score=0.498036 -   0.4s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=6, n_estimators=200, subsample=0.8
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=6, n_estimators=200, subsample=0.6, score=0.854047 -   0.4s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=6, n_estimators=200, subsample=0.8
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=6, n_estimators=200, subsample=0.8, score=0.689506 -   0.4s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=6, n_estimators=500, subsample=0.6
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=6, n_estimators=200, subsample=0.6, score=0.592857 -   0.5s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=6, n_estimators=500, subsample=0.6
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=6, n_estimators=200, subsample=0.8, score=0.344554 -   0.5s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=6, n_estimators=500, subsample=0.6
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=4, n_estimators=500, subsample=0.8, score=0.548571 -   1.0s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=6, n_estimators=500, subsample=0.6
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=4, n_estimators=500, subsample=0.8, score=0.844245 -   1.0s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=6, n_estimators=500, subsample=0.6
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=6, n_estimators=200, subsample=0.8, score=0.857554 -   0.4s
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=6, n_estimators=200, subsample=0.8, score=0.509911 -   0.5s
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=6, n_estimators=200, subsample=0.8, score=0.574732 -   0.4s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=6, n_estimators=500, subsample=0.8
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=6, n_estimators=500, subsample=0.8
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=6, n_estimators=500, subsample=0.8
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=6, n_estimators=500, subsample=0.6, score=0.537390 -   1.0s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=6, n_estimators=500, subsample=0.8
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=6, n_estimators=500, subsample=0.6, score=0.263304 -   1.0s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=6, n_estimators=500, subsample=0.8
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=6, n_estimators=500, subsample=0.6, score=0.445982 -   1.1s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=2, n_estimators=200, subsample=0.6
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=6, n_estimators=500, subsample=0.8, score=0.462232 -   0.9s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=2, n_estimators=200, subsample=0.6
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=6, n_estimators=500, subsample=0.6, score=0.843435 -   1.2s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=2, n_estimators=200, subsample=0.6
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=6, n_estimators=500, subsample=0.6, score=0.555536 -   1.3s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=2, n_estimators=200, subsample=0.6
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=6, n_estimators=500, subsample=0.8, score=0.252143 -   1.2s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=2, n_estimators=200, subsample=0.6
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=6, n_estimators=500, subsample=0.8, score=0.596561 -   1.2s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=2, n_estimators=200, subsample=0.8
# [Parallel(n_jobs=-1)]: Done  56 tasks      | elapsed:    5.6s
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=6, n_estimators=500, subsample=0.8, score=0.832914 -   1.2s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=2, n_estimators=200, subsample=0.8
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=2, n_estimators=200, subsample=0.6, score=0.434480 -   1.0s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=2, n_estimators=200, subsample=0.8
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=2, min_child_weight=6, n_estimators=500, subsample=0.8, score=0.540536 -   1.2s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=2, n_estimators=200, subsample=0.8
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=2, n_estimators=200, subsample=0.6, score=0.288929 -   1.0s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=2, n_estimators=200, subsample=0.8
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=2, n_estimators=200, subsample=0.6, score=0.454911 -   0.9s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=2, n_estimators=500, subsample=0.6
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=2, n_estimators=200, subsample=0.8, score=0.545150 -   0.9s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=2, n_estimators=500, subsample=0.6
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=2, n_estimators=200, subsample=0.6, score=0.537589 -   1.0s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=2, n_estimators=500, subsample=0.6
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=2, n_estimators=200, subsample=0.6, score=0.820234 -   1.1s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=2, n_estimators=500, subsample=0.6
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=2, n_estimators=200, subsample=0.8, score=0.255625 -   0.8s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=2, n_estimators=500, subsample=0.6
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=2, n_estimators=200, subsample=0.8, score=0.560625 -   0.8s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=2, n_estimators=500, subsample=0.8
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=2, n_estimators=200, subsample=0.8, score=0.453125 -   0.9s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=2, n_estimators=500, subsample=0.8
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=2, n_estimators=200, subsample=0.8, score=0.842536 -   0.9s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=2, n_estimators=500, subsample=0.8
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=2, n_estimators=500, subsample=0.6, score=0.272411 -   2.0s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=2, n_estimators=500, subsample=0.8
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=2, n_estimators=500, subsample=0.6, score=0.443827 -   2.1s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=2, n_estimators=500, subsample=0.8
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=2, n_estimators=500, subsample=0.6, score=0.425804 -   2.0s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=4, n_estimators=200, subsample=0.6
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=2, n_estimators=500, subsample=0.6, score=0.537679 -   2.2s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=4, n_estimators=200, subsample=0.6
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=2, n_estimators=500, subsample=0.8, score=0.506878 -   2.1s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=4, n_estimators=200, subsample=0.6
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=2, n_estimators=500, subsample=0.8, score=0.435714 -   2.1s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=4, n_estimators=200, subsample=0.6
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=4, n_estimators=200, subsample=0.6, score=0.497795 -   0.9s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=4, n_estimators=200, subsample=0.6
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=2, n_estimators=500, subsample=0.6, score=0.805755 -   2.4s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=4, n_estimators=200, subsample=0.8
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=2, n_estimators=500, subsample=0.8, score=0.264286 -   2.3s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=4, n_estimators=200, subsample=0.8
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=4, n_estimators=200, subsample=0.6, score=0.305714 -   0.9s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=4, n_estimators=200, subsample=0.8
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=4, n_estimators=200, subsample=0.6, score=0.580268 -   0.6s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=4, n_estimators=200, subsample=0.8
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=4, n_estimators=200, subsample=0.6, score=0.443482 -   0.9s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=4, n_estimators=200, subsample=0.8
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=4, n_estimators=200, subsample=0.6, score=0.838759 -   0.8s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=4, n_estimators=500, subsample=0.6
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=4, n_estimators=200, subsample=0.8, score=0.551323 -   0.8s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=4, n_estimators=500, subsample=0.6
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=4, n_estimators=200, subsample=0.8, score=0.275357 -   0.8s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=4, n_estimators=500, subsample=0.6
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=4, n_estimators=200, subsample=0.8, score=0.440268 -   0.8s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=4, n_estimators=500, subsample=0.6
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=2, n_estimators=500, subsample=0.8, score=0.813489 -   2.2s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=4, n_estimators=500, subsample=0.6
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=2, n_estimators=500, subsample=0.8, score=0.549196 -   2.2s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=4, n_estimators=500, subsample=0.8
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=4, n_estimators=200, subsample=0.8, score=0.549732 -   0.8s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=4, n_estimators=500, subsample=0.8
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=4, n_estimators=200, subsample=0.8, score=0.826349 -   0.7s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=4, n_estimators=500, subsample=0.8
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=4, n_estimators=500, subsample=0.6, score=0.463404 -   1.9s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=4, n_estimators=500, subsample=0.8
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=4, n_estimators=500, subsample=0.6, score=0.422946 -   1.8s
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=4, n_estimators=500, subsample=0.6, score=0.281339 -   1.9s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=4, n_estimators=500, subsample=0.8
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=6, n_estimators=200, subsample=0.6
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=4, n_estimators=500, subsample=0.6, score=0.551339 -   1.9s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=6, n_estimators=200, subsample=0.6
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=4, n_estimators=500, subsample=0.8, score=0.504938 -   1.8s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=6, n_estimators=200, subsample=0.6
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=4, n_estimators=500, subsample=0.6, score=0.819784 -   1.9s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=6, n_estimators=200, subsample=0.6
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=4, n_estimators=500, subsample=0.8, score=0.267500 -   2.0s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=6, n_estimators=200, subsample=0.6
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=4, n_estimators=500, subsample=0.8, score=0.424821 -   2.1s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=6, n_estimators=200, subsample=0.8
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=6, n_estimators=200, subsample=0.6, score=0.532275 -   0.9s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=6, n_estimators=200, subsample=0.8
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=6, n_estimators=200, subsample=0.6, score=0.323125 -   0.9s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=6, n_estimators=200, subsample=0.8
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=6, n_estimators=200, subsample=0.6, score=0.451250 -   0.8s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=6, n_estimators=200, subsample=0.8
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=6, n_estimators=200, subsample=0.6, score=0.555536 -   0.8s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=6, n_estimators=200, subsample=0.8
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=6, n_estimators=200, subsample=0.6, score=0.840288 -   0.8s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=6, n_estimators=500, subsample=0.6
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=6, n_estimators=200, subsample=0.8, score=0.287232 -   0.8s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=6, n_estimators=500, subsample=0.6
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=6, n_estimators=200, subsample=0.8, score=0.560053 -   0.9s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=6, n_estimators=500, subsample=0.6
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=4, n_estimators=500, subsample=0.8, score=0.534464 -   2.1s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=6, n_estimators=500, subsample=0.6
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=6, n_estimators=200, subsample=0.8, score=0.552500 -   0.9s
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=4, n_estimators=500, subsample=0.8, score=0.805126 -   2.1s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=6, n_estimators=500, subsample=0.6
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=6, n_estimators=500, subsample=0.8
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=6, n_estimators=200, subsample=0.8, score=0.452411 -   1.0s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=6, n_estimators=500, subsample=0.8
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=6, n_estimators=200, subsample=0.8, score=0.838040 -   1.1s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=6, n_estimators=500, subsample=0.8
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=6, n_estimators=500, subsample=0.6, score=0.460670 -   2.0s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=6, n_estimators=500, subsample=0.8
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=6, n_estimators=500, subsample=0.6, score=0.408125 -   2.2s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=6, n_estimators=500, subsample=0.8
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=6, n_estimators=500, subsample=0.6, score=0.277321 -   2.2s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=2, n_estimators=200, subsample=0.6
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=6, n_estimators=500, subsample=0.6, score=0.536875 -   2.0s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=2, n_estimators=200, subsample=0.6
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=6, n_estimators=500, subsample=0.8, score=0.506173 -   2.0s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=2, n_estimators=200, subsample=0.6
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=6, n_estimators=500, subsample=0.6, score=0.823831 -   2.0s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=2, n_estimators=200, subsample=0.6
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=6, n_estimators=500, subsample=0.8, score=0.267500 -   2.1s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=2, n_estimators=200, subsample=0.6
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=6, n_estimators=500, subsample=0.8, score=0.423036 -   2.1s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=2, n_estimators=200, subsample=0.8
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=2, n_estimators=200, subsample=0.6, score=0.298482 -   1.1s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=2, n_estimators=200, subsample=0.8
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=2, n_estimators=200, subsample=0.6, score=0.481922 -   1.3s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=2, n_estimators=200, subsample=0.8
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=2, n_estimators=200, subsample=0.6, score=0.458304 -   1.2s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=2, n_estimators=200, subsample=0.8
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=2, n_estimators=200, subsample=0.6, score=0.581696 -   1.3s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=2, n_estimators=200, subsample=0.8
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=2, n_estimators=200, subsample=0.6, score=0.809982 -   1.3s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=2, n_estimators=500, subsample=0.6
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=6, n_estimators=500, subsample=0.8, score=0.538036 -   2.2s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=2, n_estimators=500, subsample=0.6
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=2, n_estimators=200, subsample=0.8, score=0.524250 -   1.4s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=2, n_estimators=500, subsample=0.6
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=4, min_child_weight=6, n_estimators=500, subsample=0.8, score=0.820414 -   2.2s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=2, n_estimators=500, subsample=0.6
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=2, n_estimators=200, subsample=0.8, score=0.271518 -   1.3s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=2, n_estimators=500, subsample=0.6
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=2, n_estimators=200, subsample=0.8, score=0.567768 -   1.3s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=2, n_estimators=500, subsample=0.8
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=2, n_estimators=200, subsample=0.8, score=0.453661 -   1.5s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=2, n_estimators=500, subsample=0.8
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=2, n_estimators=200, subsample=0.8, score=0.824191 -   1.4s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=2, n_estimators=500, subsample=0.8
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=2, n_estimators=500, subsample=0.6, score=0.445591 -   3.2s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=2, n_estimators=500, subsample=0.8
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=2, n_estimators=500, subsample=0.6, score=0.440179 -   2.9s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=2, n_estimators=500, subsample=0.8
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=2, n_estimators=500, subsample=0.6, score=0.288214 -   3.1s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=4, n_estimators=200, subsample=0.6
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=2, n_estimators=500, subsample=0.6, score=0.562321 -   2.9s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=4, n_estimators=200, subsample=0.6
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=2, n_estimators=500, subsample=0.6, score=0.804676 -   2.9s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=4, n_estimators=200, subsample=0.6
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=2, n_estimators=500, subsample=0.8, score=0.490476 -   3.0s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=4, n_estimators=200, subsample=0.6
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=2, n_estimators=500, subsample=0.8, score=0.276429 -   2.9s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=4, n_estimators=200, subsample=0.6
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=2, n_estimators=500, subsample=0.8, score=0.438929 -   2.9s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=4, n_estimators=200, subsample=0.8
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=4, n_estimators=200, subsample=0.6, score=0.535979 -   1.1s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=4, n_estimators=200, subsample=0.8
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=4, n_estimators=200, subsample=0.6, score=0.300893 -   1.2s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=4, n_estimators=200, subsample=0.8
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=4, n_estimators=200, subsample=0.6, score=0.437589 -   1.1s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=4, n_estimators=200, subsample=0.8
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=4, n_estimators=200, subsample=0.6, score=0.575179 -   1.1s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=4, n_estimators=200, subsample=0.8
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=4, n_estimators=200, subsample=0.6, score=0.822392 -   1.1s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=4, n_estimators=500, subsample=0.6
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=4, n_estimators=200, subsample=0.8, score=0.530600 -   1.1s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=4, n_estimators=500, subsample=0.6
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=4, n_estimators=200, subsample=0.8, score=0.277857 -   1.0s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=4, n_estimators=500, subsample=0.6
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=4, n_estimators=200, subsample=0.8, score=0.442500 -   1.0s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=4, n_estimators=500, subsample=0.6
# [Parallel(n_jobs=-1)]: Done 146 tasks      | elapsed:   23.6s
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=2, n_estimators=500, subsample=0.8, score=0.565536 -   2.7s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=4, n_estimators=500, subsample=0.6
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=4, n_estimators=200, subsample=0.8, score=0.554821 -   1.1s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=4, n_estimators=500, subsample=0.8
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=2, n_estimators=500, subsample=0.8, score=0.810342 -   2.9s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=4, n_estimators=500, subsample=0.8
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=4, n_estimators=200, subsample=0.8, score=0.816637 -   1.2s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=4, n_estimators=500, subsample=0.8
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=4, n_estimators=500, subsample=0.6, score=0.284643 -   2.5s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=4, n_estimators=500, subsample=0.8
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=4, n_estimators=500, subsample=0.6, score=0.501675 -   2.7s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=4, n_estimators=500, subsample=0.8
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=4, n_estimators=500, subsample=0.6, score=0.425446 -   2.5s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=6, n_estimators=200, subsample=0.6
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=4, n_estimators=500, subsample=0.6, score=0.556964 -   2.5s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=6, n_estimators=200, subsample=0.6
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=4, n_estimators=500, subsample=0.6, score=0.812320 -   2.9s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=6, n_estimators=200, subsample=0.6
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=4, n_estimators=500, subsample=0.8, score=0.510053 -   2.8s
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=4, n_estimators=500, subsample=0.8, score=0.273750 -   2.9s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=6, n_estimators=200, subsample=0.6
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=6, n_estimators=200, subsample=0.6
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=4, n_estimators=500, subsample=0.8, score=0.431161 -   2.8s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=6, n_estimators=200, subsample=0.8
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=6, n_estimators=200, subsample=0.6, score=0.541270 -   1.2s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=6, n_estimators=200, subsample=0.8
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=6, n_estimators=200, subsample=0.6, score=0.329464 -   1.1s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=6, n_estimators=200, subsample=0.8
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=6, n_estimators=200, subsample=0.6, score=0.464732 -   1.1s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=6, n_estimators=200, subsample=0.8
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=6, n_estimators=200, subsample=0.6, score=0.845594 -   1.0s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=6, n_estimators=200, subsample=0.8
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=6, n_estimators=200, subsample=0.6, score=0.570179 -   1.0s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=6, n_estimators=500, subsample=0.6
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=6, n_estimators=200, subsample=0.8, score=0.546384 -   1.0s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=6, n_estimators=500, subsample=0.6
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=6, n_estimators=200, subsample=0.8, score=0.299018 -   1.1s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=6, n_estimators=500, subsample=0.6
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=6, n_estimators=200, subsample=0.8, score=0.455000 -   1.2s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=6, n_estimators=500, subsample=0.6
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=6, n_estimators=200, subsample=0.8, score=0.832194 -   1.3s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=6, n_estimators=500, subsample=0.6
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=4, n_estimators=500, subsample=0.8, score=0.549643 -   3.4s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=6, n_estimators=500, subsample=0.8
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=6, n_estimators=200, subsample=0.8, score=0.558661 -   1.4s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=6, n_estimators=500, subsample=0.8
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=4, n_estimators=500, subsample=0.8, score=0.798112 -   3.5s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=6, n_estimators=500, subsample=0.8
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=6, n_estimators=500, subsample=0.6, score=0.501764 -   2.6s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=6, n_estimators=500, subsample=0.8
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=6, n_estimators=500, subsample=0.6, score=0.432321 -   2.7s
# [CV] colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=6, n_estimators=500, subsample=0.8
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=6, n_estimators=500, subsample=0.6, score=0.284911 -   3.0s
# [CV] colsample_bytree=0.5, learning_rate=0.2, max_depth=2, min_child_weight=2, n_estimators=200, subsample=0.6
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=6, n_estimators=500, subsample=0.6, score=0.555268 -   2.9s
# [CV] colsample_bytree=0.5, learning_rate=0.2, max_depth=2, min_child_weight=2, n_estimators=200, subsample=0.6
# [CV]  colsample_bytree=0.5, learning_rate=0.2, max_depth=2, min_child_weight=2, n_estimators=200, subsample=0.6, score=0.461376 -   0.5s
# [CV] colsample_bytree=0.5, learning_rate=0.2, max_depth=2, min_child_weight=2, n_estimators=200, subsample=0.6
# [CV]  colsample_bytree=0.5, learning_rate=0.2, max_depth=2, min_child_weight=2, n_estimators=200, subsample=0.6, score=0.276607 -   0.5s
# [CV] colsample_bytree=0.5, learning_rate=0.2, max_depth=2, min_child_weight=2, n_estimators=200, subsample=0.6
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=6, n_estimators=500, subsample=0.6, score=0.827788 -   2.7s
# [CV] colsample_bytree=0.5, learning_rate=0.2, max_depth=2, min_child_weight=2, n_estimators=200, subsample=0.6
# [CV]  colsample_bytree=0.5, learning_rate=0.2, max_depth=2, min_child_weight=2, n_estimators=200, subsample=0.6, score=0.481161 -   0.5s
# [CV] colsample_bytree=0.5, learning_rate=0.2, max_depth=2, min_child_weight=2, n_estimators=200, subsample=0.8
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=6, n_estimators=500, subsample=0.8, score=0.287232 -   2.9s
# [CV] colsample_bytree=0.5, learning_rate=0.2, max_depth=2, min_child_weight=2, n_estimators=200, subsample=0.8
# [CV]  colsample_bytree=0.5, learning_rate=0.2, max_depth=2, min_child_weight=2, n_estimators=200, subsample=0.6, score=0.537679 -   0.4s
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=6, n_estimators=500, subsample=0.8, score=0.507319 -   3.0s
# [CV] colsample_bytree=0.5, learning_rate=0.2, max_depth=2, min_child_weight=2, n_estimators=200, subsample=0.8
# [CV] colsample_bytree=0.5, learning_rate=0.2, max_depth=2, min_child_weight=2, n_estimators=200, subsample=0.8
# [CV]  colsample_bytree=0.5, learning_rate=0.1, max_depth=6, min_child_weight=6, n_estimators=500, subsample=0.8, score=0.440089 -   3.0s
# [CV] colsample_bytree=0.5, learning_rate=0.2, max_depth=2, min_child_weight=2, n_estimators=200, subsample=0.8
# [CV]  colsample_bytree=0.5, learning_rate=0.2, max_depth=2, min_child_weight=2, n_estimators=200, subsample=0.6, score=0.841906 -   0.6s
# [CV] colsample_bytree=0.5, learning_rate=0.2, max_depth=2, min_child_weight=2, n_estimators=500, subsample=0.6
# [CV]  colsample_bytree=0.5, learning_rate=0.2, max_depth=2, min_child_weight=2, n_estimators=200, subsample=0.8, score=0.522487 -   0.6s
# [CV] colsample_bytree=0.5, learning_rate=0.2, max_depth=2, min_child_weight=2, n_estimators=500, subsample=0.6
# [CV]  colsample_bytree=0.5, learning_rate=0.2, max_depth=2, min_child_weight=2, n_estimators=200, subsample=0.8, score=0.562589 -   0.5s
# [CV] colsample_bytree=0.5, learning_rate=0.2, max_depth=2, min_child_weight=2, n_estimators=500, subsample=0.6
# [CV]  colsample_bytree=0.5, learning_rate=0.2, max_depth=2, min_child_weight=2, n_estimators=200, subsample=0.8, score=0.234464 -   0.7s
# [CV] colsample_bytree=0.5, learning_rate=0.2, max_depth=2, min_child_weight=2, n_estimators=500, subsample=0.6
# [CV]  colsample_bytree=0.5, learning_rate=0.2, max_depth=2, min_child_weight=2, n_estimators=200, subsample=0.8, score=0.829317 -   0.7s
# [CV] colsample_bytree=0.5, learning_rate=0.2, max_depth=2, min_child_weight=2, n_estimators=500, subsample=0.6
# [CV]  colsample_bytree=0.5, learning_rate=0.2, max_depth=2, min_child_weight=2, n_estimators=200, subsample=0.8, score=0.455000 -   0.7s
# [CV] colsample_bytree=0.5, learning_rate=0.2, max_depth=2, min_child_weight=2, n_estimators=500, subsample=0.8
# ...
# [CV] colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=2, n_estimators=200, subsample=0.6
# [CV]  colsample_bytree=0.8, learning_rate=0.3, max_depth=4, min_child_weight=6, n_estimators=500, subsample=0.8, score=0.257321 -   2.8s
# [CV] colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=2, n_estimators=200, subsample=0.6
# [CV]  colsample_bytree=0.8, learning_rate=0.3, max_depth=4, min_child_weight=6, n_estimators=500, subsample=0.8, score=0.414018 -   2.6s
# [CV] colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=2, n_estimators=200, subsample=0.8
# [CV]  colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=2, n_estimators=200, subsample=0.6, score=0.462169 -   1.7s
# [CV] colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=2, n_estimators=200, subsample=0.8
# [CV]  colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=2, n_estimators=200, subsample=0.6, score=0.307679 -   1.7s
# [CV] colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=2, n_estimators=200, subsample=0.8
# [CV]  colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=2, n_estimators=200, subsample=0.6, score=0.433125 -   1.6s
# [CV] colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=2, n_estimators=200, subsample=0.8
# [CV]  colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=2, n_estimators=200, subsample=0.6, score=0.549911 -   1.6s
# [CV] colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=2, n_estimators=200, subsample=0.8
# [CV]  colsample_bytree=0.8, learning_rate=0.3, max_depth=4, min_child_weight=6, n_estimators=500, subsample=0.8, score=0.545714 -   2.7s
# [CV]  colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=2, n_estimators=200, subsample=0.6, score=0.811511 -   1.8s
# [CV] colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=2, n_estimators=500, subsample=0.6
# [CV] colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=2, n_estimators=500, subsample=0.6
# [CV]  colsample_bytree=0.8, learning_rate=0.3, max_depth=4, min_child_weight=6, n_estimators=500, subsample=0.8, score=0.783004 -   2.7s
# [CV] colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=2, n_estimators=500, subsample=0.6
# [CV]  colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=2, n_estimators=200, subsample=0.8, score=0.470018 -   1.8s
# [CV] colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=2, n_estimators=500, subsample=0.6
# [CV]  colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=2, n_estimators=200, subsample=0.8, score=0.303304 -   1.5s
# [CV] colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=2, n_estimators=500, subsample=0.6
# [CV]  colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=2, n_estimators=200, subsample=0.8, score=0.418750 -   1.6s
# [CV] colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=2, n_estimators=500, subsample=0.8
# [CV]  colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=2, n_estimators=200, subsample=0.8, score=0.539464 -   1.7s
# [CV] colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=2, n_estimators=500, subsample=0.8
# [CV]  colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=2, n_estimators=200, subsample=0.8, score=0.801619 -   1.7s
# [CV] colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=2, n_estimators=500, subsample=0.8
# [CV]  colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=2, n_estimators=500, subsample=0.6, score=0.472928 -   3.2s
# [CV] colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=2, n_estimators=500, subsample=0.8
# [CV]  colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=2, n_estimators=500, subsample=0.6, score=0.314554 -   3.6s
# [CV] colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=2, n_estimators=500, subsample=0.8
# [CV]  colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=2, n_estimators=500, subsample=0.6, score=0.445982 -   3.8s
# [CV] colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=4, n_estimators=200, subsample=0.6
# [CV]  colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=2, n_estimators=500, subsample=0.6, score=0.561250 -   3.7s
# [CV] colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=4, n_estimators=200, subsample=0.6
# [CV]  colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=2, n_estimators=500, subsample=0.6, score=0.806025 -   3.6s
# [CV] colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=4, n_estimators=200, subsample=0.6
# [CV]  colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=2, n_estimators=500, subsample=0.8, score=0.314464 -   3.4s
# [CV] colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=4, n_estimators=200, subsample=0.6
# [CV]  colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=2, n_estimators=500, subsample=0.8, score=0.407857 -   3.4s
# [CV] colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=4, n_estimators=200, subsample=0.6
# [CV]  colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=2, n_estimators=500, subsample=0.8, score=0.450176 -   3.7s
# [CV] colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=4, n_estimators=200, subsample=0.8
# [CV]  colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=4, n_estimators=200, subsample=0.6, score=0.482187 -   1.5s
# [CV] colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=4, n_estimators=200, subsample=0.8
# [CV]  colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=4, n_estimators=200, subsample=0.6, score=0.279554 -   1.6s
# [CV] colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=4, n_estimators=200, subsample=0.8
# [CV]  colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=4, n_estimators=200, subsample=0.6, score=0.439554 -   1.4s
# [CV] colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=4, n_estimators=200, subsample=0.8
# [CV]  colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=4, n_estimators=200, subsample=0.6, score=0.582589 -   1.7s
# [CV] colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=4, n_estimators=200, subsample=0.8
# [CV]  colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=4, n_estimators=200, subsample=0.6, score=0.750450 -   1.7s
# [CV] colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=4, n_estimators=500, subsample=0.6
# [CV]  colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=4, n_estimators=200, subsample=0.8, score=0.484656 -   1.7s
# [CV] colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=4, n_estimators=500, subsample=0.6
# [CV]  colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=2, n_estimators=500, subsample=0.8, score=0.545893 -   3.7s
# [CV] colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=4, n_estimators=500, subsample=0.6
# [CV]  colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=4, n_estimators=200, subsample=0.8, score=0.303750 -   1.6s
# [CV] colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=4, n_estimators=500, subsample=0.6
# [CV]  colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=4, n_estimators=200, subsample=0.8, score=0.430625 -   1.5s
# [CV] colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=4, n_estimators=500, subsample=0.6
# [CV]  colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=4, n_estimators=200, subsample=0.8, score=0.547946 -   1.5s
# [CV] colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=4, n_estimators=500, subsample=0.8
# [CV]  colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=2, n_estimators=500, subsample=0.8, score=0.804406 -   3.8s
# [CV] colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=4, n_estimators=500, subsample=0.8
# [CV]  colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=4, n_estimators=200, subsample=0.8, score=0.810072 -   1.7s
# [CV] colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=4, n_estimators=500, subsample=0.8
# [CV]  colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=4, n_estimators=500, subsample=0.6, score=0.512257 -   3.2s
# [CV] colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=4, n_estimators=500, subsample=0.8
# [CV]  colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=4, n_estimators=500, subsample=0.6, score=0.278750 -   3.2s
# [CV] colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=4, n_estimators=500, subsample=0.8
# [CV]  colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=4, n_estimators=500, subsample=0.6, score=0.425446 -   3.0s
# [CV] colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=6, n_estimators=200, subsample=0.6
# [CV]  colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=4, n_estimators=500, subsample=0.6, score=0.565893 -   3.3s
# [CV] colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=6, n_estimators=200, subsample=0.6
# [CV]  colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=4, n_estimators=500, subsample=0.6, score=0.755845 -   3.5s
# [CV] colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=6, n_estimators=200, subsample=0.6
# [CV]  colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=4, n_estimators=500, subsample=0.8, score=0.299375 -   3.2s
# [CV] colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=6, n_estimators=200, subsample=0.6
# [CV]  colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=4, n_estimators=500, subsample=0.8, score=0.475926 -   3.4s
# [CV] colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=6, n_estimators=200, subsample=0.6
# [CV]  colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=6, n_estimators=200, subsample=0.6, score=0.457584 -   1.2s
# [CV] colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=6, n_estimators=200, subsample=0.8
# [CV]  colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=4, n_estimators=500, subsample=0.8, score=0.435446 -   3.4s
# [CV] colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=6, n_estimators=200, subsample=0.8
# [CV]  colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=6, n_estimators=200, subsample=0.6, score=0.288482 -   1.3s
# [CV] colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=6, n_estimators=200, subsample=0.8
# [CV]  colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=6, n_estimators=200, subsample=0.6, score=0.430714 -   1.5s
# [CV] colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=6, n_estimators=200, subsample=0.8
# [CV]  colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=6, n_estimators=200, subsample=0.6, score=0.536607 -   1.4s
# [CV] colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=6, n_estimators=200, subsample=0.8
# [CV]  colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=6, n_estimators=200, subsample=0.6, score=0.797662 -   1.5s
# [CV] colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=6, n_estimators=500, subsample=0.6
# [CV]  colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=6, n_estimators=200, subsample=0.8, score=0.507231 -   1.6s
# [CV] colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=6, n_estimators=500, subsample=0.6
# [CV]  colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=6, n_estimators=200, subsample=0.8, score=0.271429 -   1.4s
# [CV] colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=6, n_estimators=500, subsample=0.6
# [CV]  colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=6, n_estimators=200, subsample=0.8, score=0.448571 -   1.4s
# [CV] colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=6, n_estimators=500, subsample=0.6
# [CV]  colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=4, n_estimators=500, subsample=0.8, score=0.540982 -   3.4s
# [CV] colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=6, n_estimators=500, subsample=0.6
# [CV]  colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=4, n_estimators=500, subsample=0.8, score=0.801619 -   3.4s
# [CV] colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=6, n_estimators=500, subsample=0.8
# [CV]  colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=6, n_estimators=200, subsample=0.8, score=0.530179 -   1.5s
# [CV] colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=6, n_estimators=500, subsample=0.8
# [CV]  colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=6, n_estimators=200, subsample=0.8, score=0.816277 -   1.6s
# [CV] colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=6, n_estimators=500, subsample=0.8
# [CV]  colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=6, n_estimators=500, subsample=0.6, score=0.480071 -   2.9s
# [CV] colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=6, n_estimators=500, subsample=0.8
# [CV]  colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=6, n_estimators=500, subsample=0.6, score=0.275179 -   3.0s
# [CV] colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=6, n_estimators=500, subsample=0.8
# [CV]  colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=6, n_estimators=500, subsample=0.6, score=0.434286 -   3.0s
# [CV]  colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=6, n_estimators=500, subsample=0.6, score=0.537679 -   3.0s
# [CV]  colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=6, n_estimators=500, subsample=0.6, score=0.791097 -   3.1s
# [CV]  colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=6, n_estimators=500, subsample=0.8, score=0.258125 -   2.8s
# [CV]  colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=6, n_estimators=500, subsample=0.8, score=0.484303 -   3.1s
# [CV]  colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=6, n_estimators=500, subsample=0.8, score=0.439464 -   2.8s
# [CV]  colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=6, n_estimators=500, subsample=0.8, score=0.526250 -   1.8s
# [CV]  colsample_bytree=0.8, learning_rate=0.3, max_depth=6, min_child_weight=6, n_estimators=500, subsample=0.8, score=0.806924 -   1.2s
# [Parallel(n_jobs=-1)]: Done 1080 out of 1080 | elapsed:  4.0min finished
# GridSearchCV(cv=5, error_score='raise',
#        estimator=XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#        n_jobs=1, nthread=4, objective='binary:logistic', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=1, silent=True,
#        subsample=1),
#        fit_params={}, iid=False, n_jobs=-1,
#        param_grid={'n_estimators': [200, 500], 'min_child_weight': [2, 4, 6], 'learning_rate': [0.1, 0.2, 0.3], 'subsample': [0.6, 0.8], 'colsample_bytree': [0.5, 0.8], 'max_depth': [2, 4, 6]},
#        pre_dispatch='2*n_jobs', refit=True, scoring='roc_auc', verbose=5)

# %%
gd_search.best_params_, gd_search.best_score_
# Out:
# ({'colsample_bytree': 0.5,
#   'learning_rate': 0.1,
#   'max_depth': 2,
#   'min_child_weight': 6,
#   'n_estimators': 200,
#   'subsample': 0.8},
#  0.5952513116490934)

# %%
import xgboost as xgb
dtrain = xgb.DMatrix(X, label=Y)

# %%
from sklearn.cross_validation import train_test_split
X_train, X_val, y_train, y_val = train_test_split(X, Y, test_size = .2, random_state=5)

# %%
dX_train = xgb.DMatrix(X_train, label=y_train)
dX_val = xgb.DMatrix(X_val, label=y_val)

# %%
params = {
    'max_depth':2,
    'min_child_weight': 6,
    'eta':0.1,
    'subsample': 0.8,
    'colsample_bytree': 0.5,
    'objective':'binary:logistic',
    'eval_metric':"auc"
}

params['eval_metric'] = 'error'
params['nthread'] = 4
params['seed'] = 1
params["booster"] = "gbtree"

# %%
watchlist = [(dX_val, 'eval')]
watchlist
# Out:
# [(<xgboost.core.DMatrix at 0x1a0dcea438>, 'eval')]

# %%
gbm = xgb.train(params, dtrain = dtrain, num_boost_round = 200, evals = watchlist, 
            early_stopping_rounds=100, 
            maximize=False, verbose_eval=10)

#gbm = train(params, dtrain, num_boost_round = 200)
# Out:
# [0]	eval-error:0.363636
# Will train until eval-error hasn't improved in 100 rounds.
# [10]	eval-error:0.263636
# [20]	eval-error:0.272727
# [30]	eval-error:0.263636
# [40]	eval-error:0.259091
# [50]	eval-error:0.25
# [60]	eval-error:0.25
# [70]	eval-error:0.240909
# [80]	eval-error:0.245455
# [90]	eval-error:0.236364
# [100]	eval-error:0.227273
# [110]	eval-error:0.218182
# [120]	eval-error:0.204545
# [130]	eval-error:0.204545
# [140]	eval-error:0.209091
# [150]	eval-error:0.209091
# [160]	eval-error:0.204545
# [170]	eval-error:0.186364
# [180]	eval-error:0.177273
# [190]	eval-error:0.177273
# [199]	eval-error:0.172727

# %%
y_val_pred = gbm.predict(dX_val)
y_val_pred[y_val_pred >= 0.5] = 1
y_val_pred[y_val_pred < 0.5] = 0

# %%
fbeta_score(beta=0.5, y_pred=y_val_pred, y_true=y_val)
# Out:
# 0.81159420289855089

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_val, y_val_pred)
cm
# Out:
# array([[126,   9],
#        [ 29,  56]])

# %%
print('Precision: ' + str(np.round(100*float((cm[1][1]))/float((cm[1][1]+cm[0][1])),2))+'%')
print('Recall: ' + str(np.round(100*float((cm[1][1]))/float((cm[1][0]+cm[1][1])),2))+'%')
# Out:
# Precision: 86.15%
# Recall: 65.88%

# %%
dtest = xgb.DMatrix(test)
dtest

# %%
y_pred = gbm.predict(dtest)

# %%
test.columns
# Out:
# Index(['Street', 'From', 'To', 'Street.Length', 'from_to', 'occ_per_1',
#        'vac_per_1', 'occ_per_2', 'vac_per_2', 'occ_per_3', 'vac_per_3',
#        'occ_per_4', 'vac_per_4', 'count', 'Month', 'Week', 'Day', 'Dayofweek',
#        'Dayofyear', 'hr', 'min', 'isweekday', 'mean_from_to_any',
#        'mean_from_to_real', 'mean_isweekday_any', 'mean_isweekday_real',
#        'mean_hr_any', 'mean_hr_real', 'mean_dow_any', 'mean_dow_real',
#        'mean_month_any', 'mean_month_real', 'lat_from', 'lon_from', 'lat_to',
#        'lon_to'],
#       dtype='object')

# %%
y = y_pred
y[y >= 0.5] = 1
y[y < 0.5] = 0

# %%
sum(y == 0), sum(y == 1)
# Out:
# (624, 102)

# %%
prediction = {"id":range(1,727), "any_spot":y}

# %%
sub_v3 = pd.DataFrame(prediction)

# %%
sub_v3 = sub_v3.astype("int")

# %%
sub_v3.to_csv("xgb_0306Tina_best_set_hypa.csv", index =False)
